# %% [markdown]
# ## Titanic Data Exploration ##
#
# ***
#
# Over the past several weeks, you've learned the code about how to explore and manipulate a dataset. Now it's time to practice what you've learned on a real-world dataset.
#
# ***
#
# ### Titanic Dataset
#
# The titanic dataset holds information about the passengers on the titanic. This includes passenger name, characteristics, and if they survived the accident. The dataset has the following columns:
#
#     * pclass = passenger class; 1 = first class, 2 = second class, 3 = third class
#     * survived = passenger survival; 1 = survived, 0 = did not survive
#     * name = passenger name
#     * sex = sex of passenger
#     * age = age of passenger
#     * sibsp = # of siblings / spouses aboard the Titanic
#     * parch = # of parents / children aboard the Titanic
#     * ticket = ticket number
#     * fare = fare paid by passenger
#     * cabin = passenger cabin
#     * embarked = port of embarkation; C = Cherbourg, Q = Queenstown, S = Southampton
#     * boat = lifeboat assignment
#     * body = recovered body number
#     * home dest = anticipated home destination
#
# If you need some additional motivation before starting, please visit: https://www.youtube.com/watch?v=3gK_2XdjOdY
#
# ### How to work through the dataset:
#
# Follow the prompts below to explore, manipulate, and visualize aspects of the dataset. Working with data takes time, so take your time as you start with a messy dataset and turn it into something that shows meaningful visualizations.
#
# ***

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# ### Import Libraries and Dataset
#
# * Review the entire notebook to determine what you will be expected to do - then, import the necessary libraries
# * Import the titanic.xlsx dataset

# %%
df = pd.read_excel("titanic.xlsx")
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S    2
# 1       male   0.9167      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male  30.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female  25.0000      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.5000      1      0    2665   14.4542      NaN        C  NaN
# 1305  female      NaN      1      0    2665   14.4542      NaN        C  NaN
# 1306    male  26.5000      0      0    2656    7.2250      NaN        C  NaN
# 1307    male  27.0000      0      0    2670    7.2250      NaN        C  NaN
# 1308    male  29.0000      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 14 columns]

# %% [markdown]
# ### Determine the Characteristics of the Dataset
#
#    * How many columns are in this dataset?
#    * How many rows are in this dataset?
#    * What types of data are in each column? Does this make sense with that you know about that column?
#    * Which variables are numeric? Which variables are categorical? What other variables are left outside of these two groups?
#    * Which variable could be considered a 'dependent' variable?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %% [markdown]
# ### Identify the Missing Data in the Dataset
#
#    * Is there any missing data?
#    * Which columns have any missing data?
#    * Which column has the most missing information? Which column has the least?

# %%
df.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
# age, fare, cabin, embarked, boat, body, home.dest

# %%
# body column has the most Nan/Null/missing data

# %% [markdown]
# ### Handling the Missing Data in the Dataset
#
#    * Remove the columns with excessive missing data (any column missing greater than 500 rows)
#    * When there is very little missing data, we can make replacements. Replace the missing data for the "embarked" column with the most common embarkation point.
#    * Replace the missing data in "fare" with the average fare of the entire sample.
#    * Remove the rows in the dataset that has missing "age" data.
#    * Recheck is there is any data missing in the dataset.

# %%
#Remove the columns with excessive missing data (any column missing greater than 500 rows)

df.drop(columns = ["cabin","boat","body","home.dest"], inplace=True)
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare embarked
# 0     female  29.0000      0      0   24160  211.3375        S
# 1       male   0.9167      1      2  113781  151.5500        S
# 2     female   2.0000      1      2  113781  151.5500        S
# 3       male  30.0000      1      2  113781  151.5500        S
# 4     female  25.0000      1      2  113781  151.5500        S
# ...      ...      ...    ...    ...     ...       ...      ...
# 1304  female  14.5000      1      0    2665   14.4542        C
# 1305  female      NaN      1      0    2665   14.4542        C
# 1306    male  26.5000      0      0    2656    7.2250        C
# 1307    male  27.0000      0      0    2670    7.2250        C
# 1308    male  29.0000      0      0  315082    7.8750        S
#
# [1309 rows x 10 columns]

# %%
#When there is very little missing data, we can make replacements. 
#Replace the missing data for the "embarked" column with the most common embarkation point.

df.loc[df["embarked"] == "NaN", "embarked"] = "Unknown"
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare embarked
# 0     female  29.0000      0      0   24160  211.3375        S
# 1       male   0.9167      1      2  113781  151.5500        S
# 2     female   2.0000      1      2  113781  151.5500        S
# 3       male  30.0000      1      2  113781  151.5500        S
# 4     female  25.0000      1      2  113781  151.5500        S
# ...      ...      ...    ...    ...     ...       ...      ...
# 1304  female  14.5000      1      0    2665   14.4542        C
# 1305  female      NaN      1      0    2665   14.4542        C
# 1306    male  26.5000      0      0    2656    7.2250        C
# 1307    male  27.0000      0      0    2670    7.2250        C
# 1308    male  29.0000      0      0  315082    7.8750        S
#
# [1309 rows x 10 columns]

# %%
#Replace the missing data in "fare" with the average fare of the entire sample.

df.loc[df["fare"] == "NaN", "fare" ] = 33.295479
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare embarked
# 0     female  29.0000      0      0   24160  211.3375        S
# 1       male   0.9167      1      2  113781  151.5500        S
# 2     female   2.0000      1      2  113781  151.5500        S
# 3       male  30.0000      1      2  113781  151.5500        S
# 4     female  25.0000      1      2  113781  151.5500        S
# ...      ...      ...    ...    ...     ...       ...      ...
# 1304  female  14.5000      1      0    2665   14.4542        C
# 1305  female      NaN      1      0    2665   14.4542        C
# 1306    male  26.5000      0      0    2656    7.2250        C
# 1307    male  27.0000      0      0    2670    7.2250        C
# 1308    male  29.0000      0      0  315082    7.8750        S
#
# [1309 rows x 10 columns]

# %%
#Remove the rows in the dataset that has missing "age" data.

df.loc[df["age"].isnull()]
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare embarked
# 0     female  29.0000      0      0   24160  211.3375        S
# 1       male   0.9167      1      2  113781  151.5500        S
# 2     female   2.0000      1      2  113781  151.5500        S
# 3       male  30.0000      1      2  113781  151.5500        S
# 4     female  25.0000      1      2  113781  151.5500        S
# ...      ...      ...    ...    ...     ...       ...      ...
# 1304  female  14.5000      1      0    2665   14.4542        C
# 1305  female      NaN      1      0    2665   14.4542        C
# 1306    male  26.5000      0      0    2656    7.2250        C
# 1307    male  27.0000      0      0    2670    7.2250        C
# 1308    male  29.0000      0      0  315082    7.8750        S
#
# [1309 rows x 10 columns]

# %%
df.dropna(inplace=True)
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1301       3         0                             Youseff, Mr. Gerious
# 1304       3         0                             Zabour, Miss. Hileni
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare embarked
# 0     female  29.0000      0      0   24160  211.3375        S
# 1       male   0.9167      1      2  113781  151.5500        S
# 2     female   2.0000      1      2  113781  151.5500        S
# 3       male  30.0000      1      2  113781  151.5500        S
# 4     female  25.0000      1      2  113781  151.5500        S
# ...      ...      ...    ...    ...     ...       ...      ...
# 1301    male  45.5000      0      0    2628    7.2250        C
# 1304  female  14.5000      1      0    2665   14.4542        C
# 1306    male  26.5000      0      0    2656    7.2250        C
# 1307    male  27.0000      0      0    2670    7.2250        C
# 1308    male  29.0000      0      0  315082    7.8750        S
#
# [1043 rows x 10 columns]

# %%
#Recheck is there is any data missing in the dataset.

df.isnull().sum()
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1301       3         0                             Youseff, Mr. Gerious
# 1304       3         0                             Zabour, Miss. Hileni
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare embarked
# 0     female  29.0000      0      0   24160  211.3375        S
# 1       male   0.9167      1      2  113781  151.5500        S
# 2     female   2.0000      1      2  113781  151.5500        S
# 3       male  30.0000      1      2  113781  151.5500        S
# 4     female  25.0000      1      2  113781  151.5500        S
# ...      ...      ...    ...    ...     ...       ...      ...
# 1301    male  45.5000      0      0    2628    7.2250        C
# 1304  female  14.5000      1      0    2665   14.4542        C
# 1306    male  26.5000      0      0    2656    7.2250        C
# 1307    male  27.0000      0      0    2670    7.2250        C
# 1308    male  29.0000      0      0  315082    7.8750        S
#
# [1043 rows x 10 columns]

# %% [markdown]
# ### Creating Columns and Replacing Labels
#
#    * Create descriptive labels for the categorical columns: pclass, survived, and embarked. Instead of the coding that shows in the dataset, create labels to describe what each category represents (i.e. in the embarked column S = Southhampton)
#    * Create a new column called "Titanic Passenger" and make all values 1
#    * Create a new column called "Family Size" - this column should equal the total number of family members each passenger was traveling with.
#    * Create a column called "Travel Alone" - this column should be 1 if the passenger was traveling alone, and 0 if the passenger was traveling with family.
#    * Create a column called "Has Caregiver" - this column should have a value of 1 if a passenger is less than 13-years old AND the passenger is traveling with at least one family member, otherwise the value should be 0.
#    * Create a column called "Crew" - this column should be 1 if the passenger paid 0 dollars for their ticket, and 0 otherwise.
#    * Create a column called "Age Group" to group passengers by their age (create five categories: infant, child, teen, adult, senior). You can use bins to complete this (or any other method you like). You define the cutoff points for each group you create.
#
# After create new columns, replace the basic coding "0/1" with meaningful labels.

# %%
#Create descriptive labels for the categorical columns: pclass, survived, and embarked. Instead of the coding that shows in the dataset, create labels to describe what each category represents (i.e. in the embarked column S = Southhampton)

#pclass column legend: 1 == "first class", 2 == "2nd class", 3 == "third class"
df["pclass"].replace([1,2,3],["first class","second class","third class"], inplace=True)
df

#survived column legend: 1 == "yes", 0 == "no"

#embarked column legend: S == "Southhampton", C == "Charlotte", Q = "Queensville"
df["embarked"].replace(["S","C","Q"],["Southhampton","Charlotte","Queensville"], inplace=True)
df
# Out:
#            pclass  survived                                             name  \
# 0     first class         1                    Allen, Miss. Elisabeth Walton
# 1     first class         1                   Allison, Master. Hudson Trevor
# 2     first class         0                     Allison, Miss. Helen Loraine
# 3     first class         0             Allison, Mr. Hudson Joshua Creighton
# 4     first class         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...           ...       ...                                              ...
# 1301  third class         0                             Youseff, Mr. Gerious
# 1304  third class         0                             Zabour, Miss. Hileni
# 1306  third class         0                        Zakarian, Mr. Mapriededer
# 1307  third class         0                              Zakarian, Mr. Ortin
# 1308  third class         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare      embarked
# 0     female  29.0000      0      0   24160  211.3375  Southhampton
# 1       male   0.9167      1      2  113781  151.5500  Southhampton
# 2     female   2.0000      1      2  113781  151.5500  Southhampton
# 3       male  30.0000      1      2  113781  151.5500  Southhampton
# 4     female  25.0000      1      2  113781  151.5500  Southhampton
# ...      ...      ...    ...    ...     ...       ...           ...
# 1301    male  45.5000      0      0    2628    7.2250     Charlotte
# 1304  female  14.5000      1      0    2665   14.4542     Charlotte
# 1306    male  26.5000      0      0    2656    7.2250     Charlotte
# 1307    male  27.0000      0      0    2670    7.2250     Charlotte
# 1308    male  29.0000      0      0  315082    7.8750  Southhampton
#
# [1043 rows x 10 columns]

# %%
#Create a new column called "Titanic Passenger" and make all values 1

df["Titanic Passenger"] = 1
df
# Out:
#            pclass  survived                                             name  \
# 0     first class         1                    Allen, Miss. Elisabeth Walton
# 1     first class         1                   Allison, Master. Hudson Trevor
# 2     first class         0                     Allison, Miss. Helen Loraine
# 3     first class         0             Allison, Mr. Hudson Joshua Creighton
# 4     first class         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...           ...       ...                                              ...
# 1301  third class         0                             Youseff, Mr. Gerious
# 1304  third class         0                             Zabour, Miss. Hileni
# 1306  third class         0                        Zakarian, Mr. Mapriededer
# 1307  third class         0                              Zakarian, Mr. Ortin
# 1308  third class         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare      embarked  \
# 0     female  29.0000      0      0   24160  211.3375  Southhampton
# 1       male   0.9167      1      2  113781  151.5500  Southhampton
# 2     female   2.0000      1      2  113781  151.5500  Southhampton
# 3       male  30.0000      1      2  113781  151.5500  Southhampton
# 4     female  25.0000      1      2  113781  151.5500  Southhampton
# ...      ...      ...    ...    ...     ...       ...           ...
# 1301    male  45.5000      0      0    2628    7.2250     Charlotte
# 1304  female  14.5000      1      0    2665   14.4542     Charlotte
# 1306    male  26.5000      0      0    2656    7.2250     Charlotte
# 1307    male  27.0000      0      0    2670    7.2250     Charlotte
# 1308    male  29.0000      0      0  315082    7.8750  Southhampton
#
#       Titanic Passenger
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1
# ...                 ...
# 1301                  1
# 1304                  1
# 1306                  1
# 1307                  1
# 1308                  1
#
# [1043 rows x 11 columns]

# %%
#Create a new column called "Family Size" - this column should equal the total number of family members each passenger was traveling with.

df["Family Size"] = df["sibsp"] + df["parch"]
df
# Out:
#            pclass  survived                                             name  \
# 0     first class         1                    Allen, Miss. Elisabeth Walton
# 1     first class         1                   Allison, Master. Hudson Trevor
# 2     first class         0                     Allison, Miss. Helen Loraine
# 3     first class         0             Allison, Mr. Hudson Joshua Creighton
# 4     first class         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...           ...       ...                                              ...
# 1301  third class         0                             Youseff, Mr. Gerious
# 1304  third class         0                             Zabour, Miss. Hileni
# 1306  third class         0                        Zakarian, Mr. Mapriededer
# 1307  third class         0                              Zakarian, Mr. Ortin
# 1308  third class         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare      embarked  \
# 0     female  29.0000      0      0   24160  211.3375  Southhampton
# 1       male   0.9167      1      2  113781  151.5500  Southhampton
# 2     female   2.0000      1      2  113781  151.5500  Southhampton
# 3       male  30.0000      1      2  113781  151.5500  Southhampton
# 4     female  25.0000      1      2  113781  151.5500  Southhampton
# ...      ...      ...    ...    ...     ...       ...           ...
# 1301    male  45.5000      0      0    2628    7.2250     Charlotte
# 1304  female  14.5000      1      0    2665   14.4542     Charlotte
# 1306    male  26.5000      0      0    2656    7.2250     Charlotte
# 1307    male  27.0000      0      0    2670    7.2250     Charlotte
# 1308    male  29.0000      0      0  315082    7.8750  Southhampton
#
#       Titanic Passenger  Family Size
# 0                     1            0
# 1                     1            3
# 2                     1            3
# 3                     1            3
# 4                     1            3
# ...                 ...          ...
# 1301                  1            0
# 1304                  1            1
# 1306                  1            0
# 1307                  1            0
# 1308                  1            0
#
# [1043 rows x 12 columns]

# %%
#Create a column called "Travel Alone"
#this column should be 1 if the passenger was traveling alone, and 0 if the passenger was traveling with family.

df["Travel Alone"] = df["Family Size"].apply(lambda x: 0 if x == 0 else 1) 
df
# Out:
#            pclass  survived                                             name  \
# 0     first class         1                    Allen, Miss. Elisabeth Walton
# 1     first class         1                   Allison, Master. Hudson Trevor
# 2     first class         0                     Allison, Miss. Helen Loraine
# 3     first class         0             Allison, Mr. Hudson Joshua Creighton
# 4     first class         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...           ...       ...                                              ...
# 1301  third class         0                             Youseff, Mr. Gerious
# 1304  third class         0                             Zabour, Miss. Hileni
# 1306  third class         0                        Zakarian, Mr. Mapriededer
# 1307  third class         0                              Zakarian, Mr. Ortin
# 1308  third class         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare      embarked  \
# 0     female  29.0000      0      0   24160  211.3375  Southhampton
# 1       male   0.9167      1      2  113781  151.5500  Southhampton
# 2     female   2.0000      1      2  113781  151.5500  Southhampton
# 3       male  30.0000      1      2  113781  151.5500  Southhampton
# 4     female  25.0000      1      2  113781  151.5500  Southhampton
# ...      ...      ...    ...    ...     ...       ...           ...
# 1301    male  45.5000      0      0    2628    7.2250     Charlotte
# 1304  female  14.5000      1      0    2665   14.4542     Charlotte
# 1306    male  26.5000      0      0    2656    7.2250     Charlotte
# 1307    male  27.0000      0      0    2670    7.2250     Charlotte
# 1308    male  29.0000      0      0  315082    7.8750  Southhampton
#
#       Titanic Passenger  Family Size  Travel Alone
# 0                     1            0             0
# 1                     1            3             1
# 2                     1            3             1
# 3                     1            3             1
# 4                     1            3             1
# ...                 ...          ...           ...
# 1301                  1            0             0
# 1304                  1            1             1
# 1306                  1            0             0
# 1307                  1            0             0
# 1308                  1            0             0
#
# [1043 rows x 13 columns]

# %%
#Create a column called "Has Caregiver" 
#this column should have a value of 1 if a passenger is less than 13-years old AND the passenger is traveling with at least one family member, 
#otherwise the value should be 0.

df["Has Caregiver"] = np.where((df["age"] <= 13) & (df["Family Size"] == 1), 1,0)
df
# Out:
#            pclass  survived                                             name  \
# 0     first class         1                    Allen, Miss. Elisabeth Walton
# 1     first class         1                   Allison, Master. Hudson Trevor
# 2     first class         0                     Allison, Miss. Helen Loraine
# 3     first class         0             Allison, Mr. Hudson Joshua Creighton
# 4     first class         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...           ...       ...                                              ...
# 1301  third class         0                             Youseff, Mr. Gerious
# 1304  third class         0                             Zabour, Miss. Hileni
# 1306  third class         0                        Zakarian, Mr. Mapriededer
# 1307  third class         0                              Zakarian, Mr. Ortin
# 1308  third class         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare      embarked  \
# 0     female  29.0000      0      0   24160  211.3375  Southhampton
# 1       male   0.9167      1      2  113781  151.5500  Southhampton
# 2     female   2.0000      1      2  113781  151.5500  Southhampton
# 3       male  30.0000      1      2  113781  151.5500  Southhampton
# 4     female  25.0000      1      2  113781  151.5500  Southhampton
# ...      ...      ...    ...    ...     ...       ...           ...
# 1301    male  45.5000      0      0    2628    7.2250     Charlotte
# 1304  female  14.5000      1      0    2665   14.4542     Charlotte
# 1306    male  26.5000      0      0    2656    7.2250     Charlotte
# 1307    male  27.0000      0      0    2670    7.2250     Charlotte
# 1308    male  29.0000      0      0  315082    7.8750  Southhampton
#
#       Titanic Passenger  Family Size  Travel Alone  Has Caregiver
# 0                     1            0             0              0
# 1                     1            3             1              0
# 2                     1            3             1              0
# 3                     1            3             1              0
# 4                     1            3             1              0
# ...                 ...          ...           ...            ...
# 1301                  1            0             0              0
# 1304                  1            1             1              0
# 1306                  1            0             0              0
# 1307                  1            0             0              0
# 1308                  1            0             0              0
#
# [1043 rows x 14 columns]

# %%
#Create a column called "Crew" - this column should be 1 if the passenger paid 0 dollars for their ticket, and 0 otherwise.

df["Crew"] = df["fare"].apply(lambda x:1 if x == 0 else 1)
df
# Out:
#            pclass  survived                                             name  \
# 0     first class         1                    Allen, Miss. Elisabeth Walton
# 1     first class         1                   Allison, Master. Hudson Trevor
# 2     first class         0                     Allison, Miss. Helen Loraine
# 3     first class         0             Allison, Mr. Hudson Joshua Creighton
# 4     first class         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...           ...       ...                                              ...
# 1301  third class         0                             Youseff, Mr. Gerious
# 1304  third class         0                             Zabour, Miss. Hileni
# 1306  third class         0                        Zakarian, Mr. Mapriededer
# 1307  third class         0                              Zakarian, Mr. Ortin
# 1308  third class         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare      embarked  \
# 0     female  29.0000      0      0   24160  211.3375  Southhampton
# 1       male   0.9167      1      2  113781  151.5500  Southhampton
# 2     female   2.0000      1      2  113781  151.5500  Southhampton
# 3       male  30.0000      1      2  113781  151.5500  Southhampton
# 4     female  25.0000      1      2  113781  151.5500  Southhampton
# ...      ...      ...    ...    ...     ...       ...           ...
# 1301    male  45.5000      0      0    2628    7.2250     Charlotte
# 1304  female  14.5000      1      0    2665   14.4542     Charlotte
# 1306    male  26.5000      0      0    2656    7.2250     Charlotte
# 1307    male  27.0000      0      0    2670    7.2250     Charlotte
# 1308    male  29.0000      0      0  315082    7.8750  Southhampton
#
#       Titanic Passenger  Family Size  Travel Alone  Has Caregiver  Crew
# 0                     1            0             0              0     1
# 1                     1            3             1              0     1
# 2                     1            3             1              0     1
# 3                     1            3             1              0     1
# 4                     1            3             1              0     1
# ...                 ...          ...           ...            ...   ...
# 1301                  1            0             0              0     1
# 1304                  1            1             1              0     1
# 1306                  1            0             0              0     1
# 1307                  1            0             0              0     1
# 1308                  1            0             0              0     1
#
# [1043 rows x 15 columns]

# %%
#Create a column called "Age Group" to group passengers by their age (create five categories: infant, child, teen, adult, senior). 
#You can use bins to complete this (or any other method you like). 
#You define the cutoff points for each group you create.

conditions = [(df["age"] <= 7),
              (df["age"] > 8) & (df["age"] <= 15),
              (df["age"] > 16) & (df["age"] <= 21),
              (df["age"] > 21) & (df["age"] <= 59),
              (df["age"] < 60)]
                        
outcome = ["Infant","Child","Teen","Adult","Senior"]


df["Age Group"] = np.select(conditions, outcome, default = "Unknown")

df
# Out:
#            pclass  survived                                             name  \
# 0     first class         1                    Allen, Miss. Elisabeth Walton
# 1     first class         1                   Allison, Master. Hudson Trevor
# 2     first class         0                     Allison, Miss. Helen Loraine
# 3     first class         0             Allison, Mr. Hudson Joshua Creighton
# 4     first class         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...           ...       ...                                              ...
# 1301  third class         0                             Youseff, Mr. Gerious
# 1304  third class         0                             Zabour, Miss. Hileni
# 1306  third class         0                        Zakarian, Mr. Mapriededer
# 1307  third class         0                              Zakarian, Mr. Ortin
# 1308  third class         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare      embarked  \
# 0     female  29.0000      0      0   24160  211.3375  Southhampton
# 1       male   0.9167      1      2  113781  151.5500  Southhampton
# 2     female   2.0000      1      2  113781  151.5500  Southhampton
# 3       male  30.0000      1      2  113781  151.5500  Southhampton
# 4     female  25.0000      1      2  113781  151.5500  Southhampton
# ...      ...      ...    ...    ...     ...       ...           ...
# 1301    male  45.5000      0      0    2628    7.2250     Charlotte
# 1304  female  14.5000      1      0    2665   14.4542     Charlotte
# 1306    male  26.5000      0      0    2656    7.2250     Charlotte
# 1307    male  27.0000      0      0    2670    7.2250     Charlotte
# 1308    male  29.0000      0      0  315082    7.8750  Southhampton
#
#       Titanic Passenger  Family Size  Travel Alone  Has Caregiver  Crew  \
# 0                     1            0             0              0     1
# 1                     1            3             1              0     1
# 2                     1            3             1              0     1
# 3                     1            3             1              0     1
# 4                     1            3             1              0     1
# ...                 ...          ...           ...            ...   ...
# 1301                  1            0             0              0     1
# 1304                  1            1             1              0     1
# 1306                  1            0             0              0     1
# 1307                  1            0             0              0     1
# 1308                  1            0             0              0     1
#
#      Age Group
# 0        Adult
# 1       Infant
# 2       Infant
# 3        Adult
# 4        Adult
# ...        ...
# 1301     Adult
# 1304     Child
# 1306     Adult
# 1307     Adult
# 1308     Adult
#
# [1043 rows x 16 columns]

# %% [markdown]
# ### Determine Frequencies of Groups
#
# * How many passengers fall into each category? Determine how many passengers fall into each group for <b>each</b> categorical vairable (including the ones you just created).

# %%
df["survived"].value_counts()
# Out:
# 0    618
# 1    425
# Name: survived, dtype: int64

# %%
df["sex"].value_counts()
# Out:
# male      657
# female    386
# Name: sex, dtype: int64

# %%
df["Titanic Passenger"].value_counts()
# Out:
# 1    1043
# Name: Titanic Passenger, dtype: int64

# %%
df["Family Size"].value_counts()
# Out:
# 0     587
# 1     206
# 2     144
# 3      39
# 5      25
# 4      17
# 6      16
# 7       8
# 10      1
# Name: Family Size, dtype: int64

# %%
df["Travel Alone"].value_counts()
# Out:
# 0    587
# 1    456
# Name: Travel Alone, dtype: int64

# %%
df["Has Caregiver"].value_counts()
# Out:
# 0    1033
# 1      10
# Name: Has Caregiver, dtype: int64

# %%
df["Crew"].value_counts()
# Out:
# 1    1043
# Name: Crew, dtype: int64

# %%
df["Age Group"].value_counts()
# Out:
# Adult      715
# Teen       156
# Infant      66
# Child       43
# Unknown     38
# Senior      25
# Name: Age Group, dtype: int64

# %%
df.groupby(df["Age Group"]).mean()
# Out:
#            survived        age     sibsp     parch       fare  \
# Age Group
# Adult      0.404196  34.388811  0.353846  0.321678  38.509434
# Child      0.465116  12.034884  1.767442  1.139535  39.754751
# Infant     0.636364   2.911617  1.590909  1.363636  30.148483
# Senior     0.480000  14.080000  0.920000  0.720000  25.021336
# Teen       0.326923  19.166667  0.346154  0.224359  24.901816
# Unknown    0.289474  64.618421  0.394737  0.473684  64.032568
#
#            Titanic Passenger  Family Size  Travel Alone  Has Caregiver  Crew
# Age Group
# Adult                    1.0     0.675524      0.383217       0.000000   1.0
# Child                    1.0     2.906977      0.813953       0.069767   1.0
# Infant                   1.0     2.954545      0.984848       0.106061   1.0
# Senior                   1.0     1.640000      0.560000       0.000000   1.0
# Teen                     1.0     0.570513      0.326923       0.000000   1.0
# Unknown                  1.0     0.868421      0.447368       0.000000   1.0

# %%
df.groupby(df["Travel Alone"]).mean()
# Out:
#               survived        age     sibsp     parch       fare  \
# Travel Alone
# 0             0.316865  31.399489  0.000000  0.000000  23.760028
# 1             0.524123  27.771199  1.153509  0.964912  53.135564
#
#               Titanic Passenger  Family Size  Has Caregiver  Crew
# Travel Alone
# 0                           1.0     0.000000        0.00000   1.0
# 1                           1.0     2.118421        0.02193   1.0

# %%
df.groupby(df["sex"]).mean()
# Out:
#         survived        age     sibsp     parch       fare  Titanic Passenger  \
# sex
# female  0.751295  28.576641  0.619171  0.665803  50.154934                1.0
# male    0.205479  30.539701  0.436834  0.278539  28.641019                1.0
#
#         Family Size  Travel Alone  Has Caregiver  Crew
# sex
# female     1.284974      0.613990       0.012953   1.0
# male       0.715373      0.333333       0.007610   1.0

# %%
df.groupby(df["survived"]).mean()
# Out:
#                 age     sibsp     parch       fare  Titanic Passenger  \
# survived
# 0         30.496899  0.512945  0.341424  25.148752                1.0
# 1         28.819020  0.491765  0.538824  53.258883                1.0
#
#           Family Size  Travel Alone  Has Caregiver  Crew
# survived
# 0            0.854369      0.351133       0.001618   1.0
# 1            1.030588      0.562353       0.021176   1.0

# %%
df["survived"].groupby(df["Age Group"]).mean()
# Out:
# Age Group
# Adult      0.404196
# Child      0.465116
# Infant     0.636364
# Senior     0.480000
# Teen       0.326923
# Unknown    0.289474
# Name: survived, dtype: float64

# %%
df["survived"].groupby(df["Family Size"]).mean()
# Out:
# Family Size
# 0     0.316865
# 1     0.548544
# 2     0.562500
# 3     0.769231
# 4     0.352941
# 5     0.200000
# 6     0.250000
# 7     0.000000
# 10    0.000000
# Name: survived, dtype: float64

# %%
df["survived"].groupby(df["Has Caregiver"]).mean()
# Out:
# Has Caregiver
# 0    0.402711
# 1    0.900000
# Name: survived, dtype: float64

# %%
df["survived"].groupby(df["Travel Alone"]).mean()
# Out:
# Travel Alone
# 0    0.316865
# 1    0.524123
# Name: survived, dtype: float64

# %%
pd.crosstab(df["Age Group"],df["sex"], margins=True)
# Out:
# sex        female  male   All
# Age Group
# Adult         257   458   715
# Child          22    21    43
# Infant         31    35    66
# Senior         11    14    25
# Teen           55   101   156
# Unknown        10    28    38
# All           386   657  1043

# %%
pd.crosstab(df["sex"],df["survived"], margins=True)
# Out:
# survived    0    1   All
# sex
# female     96  290   386
# male      522  135   657
# All       618  425  1043

# %%
pd.crosstab(df["sex"],["Family Size"], margins=True)
# Out:
# col_0   Family Size   All
# sex
# female          386   386
# male            657   657
# All            1043  1043

# %% [markdown]
# ### Determine the Distribution of Numeric Data
#
# * What are the summary statistics for <b>each</b> numeric variable in the dataset? Summary statistics include:
#     * Mean
#     * Median
#     * Mode
#     * Standard Deviation
#     * Range

# %%
df.describe()
# Out:
#           survived          age        sibsp        parch         fare  \
# count  1043.000000  1043.000000  1043.000000  1043.000000  1043.000000
# mean      0.407478    29.813199     0.504314     0.421860    36.603024
# std       0.491601    14.366261     0.913080     0.840655    55.753648
# min       0.000000     0.166700     0.000000     0.000000     0.000000
# 25%       0.000000    21.000000     0.000000     0.000000     8.050000
# 50%       0.000000    28.000000     0.000000     0.000000    15.750000
# 75%       1.000000    39.000000     1.000000     1.000000    35.077100
# max       1.000000    80.000000     8.000000     6.000000   512.329200
#
#        Titanic Passenger  Family Size  Travel Alone  Has Caregiver    Crew
# count             1043.0  1043.000000   1043.000000    1043.000000  1043.0
# mean                 1.0     0.926174      0.437200       0.009588     1.0
# std                  0.0     1.454134      0.496278       0.097493     0.0
# min                  1.0     0.000000      0.000000       0.000000     1.0
# 25%                  1.0     0.000000      0.000000       0.000000     1.0
# 50%                  1.0     0.000000      0.000000       0.000000     1.0
# 75%                  1.0     1.000000      1.000000       0.000000     1.0
# max                  1.0    10.000000      1.000000       1.000000     1.0

# %%
df["survived"].mean()
# Out:
# 0.4074784276126558

# %%
df["survived"].median()
# Out:
# 0.0

# %%
df["survived"].mode()
# Out:
# 0    0
# Name: survived, dtype: int64

# %%
df["survived"].std()
# Out:
# 0.49160092215607837

# %%
df["survived"].min()
# Out:
# 0

# %%
df["survived"].max()
# Out:
# 1

# %% [markdown]
# # Relationships between Variables
#
# * Determine the relationship between each variable and the variable "survived". This is our primary variable of interest -- did this passenger survive the accident? Did the characteristics of the passenger have any relationship with their survival?
#     * <b>pclass</b>: how many survivors are in each passenger class? does a pattern emerge? which class has the most survivors? which has the least?
#     * <b>sex</b>: how many survivors are in each variable group? does a pattern emerge? which group has the most survivors? which has the least?
#     * <b>age</b>: how does the average age of the passenger differ based on survival group?
#     * <b>age group</b>: how many survivors are in each variable group? does a pattern emerge? which group has the most survivors? which has the least?
#     * <b>family size</b>: how many survivors are in each variable group? does a pattern emerge? which group has the most survivors? which has the least?
#     * <b>travel alone</b>: how many survivors are in each variable group? does a pattern emerge? which group has the most survivors? which has the least?
#     * <b>crew</b>: how many survivors are in each variable group? does a pattern emerge? which group has the most survivors? which has the least?
#     * <b>has caregiver</b>: how many survivors are in each variable group? does a pattern emerge? which group has the most survivors? which has the least?
#     * <b>fare</b>: how does the average fare the passenger paid differ based on survival group?
#     * <b>embarked</b>: how many survivors are in each variable group? does a pattern emerge? which group has the most survivors? which has the least?
#
# Based on what you learn working through this section, make (2) statements about what characteristics of passenger most influenced their survival.

# %%
df.describe()
# Out:
#           survived          age        sibsp        parch         fare  \
# count  1043.000000  1043.000000  1043.000000  1043.000000  1043.000000
# mean      0.407478    29.813199     0.504314     0.421860    36.603024
# std       0.491601    14.366261     0.913080     0.840655    55.753648
# min       0.000000     0.166700     0.000000     0.000000     0.000000
# 25%       0.000000    21.000000     0.000000     0.000000     8.050000
# 50%       0.000000    28.000000     0.000000     0.000000    15.750000
# 75%       1.000000    39.000000     1.000000     1.000000    35.077100
# max       1.000000    80.000000     8.000000     6.000000   512.329200
#
#        Titanic Passenger  Family Size  Travel Alone  Has Caregiver    Crew
# count             1043.0  1043.000000   1043.000000    1043.000000  1043.0
# mean                 1.0     0.926174      0.437200       0.009588     1.0
# std                  0.0     1.454134      0.496278       0.097493     0.0
# min                  1.0     0.000000      0.000000       0.000000     1.0
# 25%                  1.0     0.000000      0.000000       0.000000     1.0
# 50%                  1.0     0.000000      0.000000       0.000000     1.0
# 75%                  1.0     1.000000      1.000000       0.000000     1.0
# max                  1.0    10.000000      1.000000       1.000000     1.0

# %%
#TThe code df["survived"].groupby(df["pclass"]).mean() represents the mean survival rate for each passenger class in the Titanic dataset. 
#The groupby() function groups the data by the pclass column, and the mean() function calculates the mean survival rate for each group.
#This output shows that first class passengers had a higher survival rate than second class passengers, who had a higher survival rate than third class passengers.

df["survived"].groupby(df["pclass"]).mean()
# Out:
# pclass
# first class     0.634752
# second class    0.440613
# third class     0.262000
# Name: survived, dtype: float64

# %%
#using groupby on the "survived" column of the dataframe as the primary variable of interest base on the passengers "sex". We are able to determine that the female tend to have a higher survival rate/percentage compared to men.

df["survived"].groupby(df["sex"]).mean()
# Out:
# sex
# female    0.751295
# male      0.205479
# Name: survived, dtype: float64

# %%
df["survived"].groupby(df["age"]).mean()

#The code df["survived"].groupby(df["age"]).mean() represents the mean survival rate for each age group in the Titanic dataset. 
#The groupby() function groups the data by the age column, and the mean() function calculates the mean survival rate for each group.
#base on the result, we are able to conclude that survival rates tend to decrease with increasing age;vice versa with younger passengers
# Out:
# age
# 0.1667     1.000000
# 0.3333     0.000000
# 0.4167     1.000000
# 0.6667     1.000000
# 0.7500     0.666667
#              ...
# 70.5000    0.000000
# 71.0000    0.000000
# 74.0000    0.000000
# 76.0000    1.000000
# 80.0000    1.000000
# Name: survived, Length: 97, dtype: float64

# %%
df["survived"].groupby(df["Age Group"]).mean()

#The statistical data at the bottom represents the percentage of the survival rates of passengers by age group.
#Infant has first highest survival rate, seniors being on the second and child being the third highest.
#The age group that has the least perentage of survival rate is "unknown"... this raises a question what types of passengers fall into these age group category... perhaps the crew memnbers and shipmates who are responsible for rescuing the passengers?
# Out:
# Age Group
# Adult      0.404196
# Child      0.465116
# Infant     0.636364
# Senior     0.480000
# Teen       0.326923
# Unknown    0.289474
# Name: survived, dtype: float64

# %%
df["survived"].groupby(df["Family Size"]).mean()

#This output shows that passengers who survived had a slightly larger family size than passengers who did not survive.
# Out:
# Family Size
# 0     0.316865
# 1     0.548544
# 2     0.562500
# 3     0.769231
# 4     0.352941
# 5     0.200000
# 6     0.250000
# 7     0.000000
# 10    0.000000
# Name: survived, dtype: float64

# %%
df["survived"].groupby(df["Travel Alone"]).mean()

#this percentage/decimal output illustrates that passengers that survive who travelled alone had a 40.7% chance of survival during the sink of titanic which is significantly less compared to the survivors who did not travel alone and travelled with a family members.
# Out:
# Travel Alone
# 0    0.316865
# 1    0.524123
# Name: survived, dtype: float64

# %%
df["survived"].groupby(df["Crew"]).mean()

#the output below signifies that only 40.7% of the crew members survived the titanic crash. The remaining percentage of the crew population didn't survive the titanic crash
# Out:
# Crew
# 1    0.407478
# Name: survived, dtype: float64

# %%
df["Has Caregiver"].value_counts()
# Out:
# 0    1033
# 1      10
# Name: Has Caregiver, dtype: int64

# %%
df["survived"].groupby(df["Has Caregiver"]).mean()

#The output below shows that only 42.4% of the survivors that travelled with a caregiver with a age of less than or equal to 13 survived the titanic crash. 
#The rest of the population that travelled with a caregiver didn't survive the crash.
# Out:
# Has Caregiver
# 0    0.402711
# 1    0.900000
# Name: survived, dtype: float64

# %%
df["fare"].value_counts()
# Out:
# 13.0000    58
# 26.0000    48
# 8.0500     38
# 10.5000    35
# 7.8958     30
#            ..
# 31.6792     1
# 7.6292      1
# 12.2750     1
# 7.8208      1
# 7.8750      1
# Name: fare, Length: 255, dtype: int64

# %%
df["survived"].groupby(df["fare"]).mean()
# Out:
# fare
# 0.0000      0.250000
# 3.1708      1.000000
# 4.0125      0.000000
# 5.0000      0.000000
# 6.2375      0.000000
#               ...
# 227.5250    0.750000
# 247.5208    0.666667
# 262.3750    0.857143
# 263.0000    0.666667
# 512.3292    1.000000
# Name: survived, Length: 255, dtype: float64

# %%
#the output/breakdown illustrates that passengers that paid a fair in lower end and higher end tend to have a higher probability rate of survival during the crash of titanic.

# %%
df.groupby(df["embarked"]).mean()

#embarked column legend: S == "Southhampton", C == "Charlotte", Q = "Queensville"
# Out:
#               survived        age     sibsp     parch       fare  \
# embarked
# Charlotte     0.622642  32.332154  0.419811  0.424528  72.474158
# Queensville   0.260000  28.630000  0.520000  0.240000  15.905918
# Southhampton  0.358515  29.205186  0.526248  0.432778  28.190956
#
#               Titanic Passenger  Family Size  Travel Alone  Has Caregiver  \
# embarked
# Charlotte                   1.0     0.844340      0.547170       0.014151
# Queensville                 1.0     0.760000      0.220000       0.000000
# Southhampton                1.0     0.959027      0.421255       0.008963
#
#               Crew
# embarked
# Charlotte      1.0
# Queensville    1.0
# Southhampton   1.0

# %%
df["survived"].groupby(df["embarked"]).mean()
# Out:
# embarked
# Charlotte       0.622642
# Queensville     0.260000
# Southhampton    0.358515
# Name: survived, dtype: float64

# %%
#according to all the output, the embarked location with the most survivors is Charlotte.

# %% [markdown]
# ### Visualize your Results
#
# * Using the most interesting (from your POV) results from the above section, create (3) visualizations to illustrate the results.
# * Create a barplot to show the variation in average age across passenger class. On average, which passenger class has the oldest passengers?
# * Create a violin plot to show the distribution of age across passenger class.

# %%
sns.barplot(data = df, x = "survived", y = "pclass", ci = None)

plt.title('Titanic Crash Survivors')
plt.grid()

# %%
sns.barplot(data = df, x = "survived", y = "embarked", ci = None)

plt.title('Titanic Crash Survivors')
plt.grid()

# %%
sns.barplot(data = df, x = "survived", y = "sex", ci = None)

plt.title('Titanic Crash Survivors')
plt.grid()

# %%
sns.countplot(data = df, x = "pclass")
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='count'>

# %%
#Create a barplot to show the variation in average age across passenger class. On average, which passenger class has the oldest passengers?

sns.barplot(data = df, x = "pclass", y = "age", ci = None)

plt.title('Titanic Crash Survivors')
plt.grid()

# %%
#Create a violin plot to show the distribution of age across passenger class.


sns.violinplot(x = df["pclass"], y = df["age"])
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='age'>
